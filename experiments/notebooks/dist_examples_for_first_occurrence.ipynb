# %%
# ###################################################
# Change current directory to the root of the project
import os
from pathlib import Path
current_dir = Path(os.getcwd())
os.chdir(current_dir.parents[1])
# ###################################################

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from cir.benchmarks.cir_utils import get_pmf

# %%
sns.set_theme()
output_path = "./"

def sample_and_plot(
        n_experiences = 20,
        n_classes = 100,
        n_different_samples = 5,
        probs=None,
        title="Title"
):
    # Data
    data = {"experiences": list(range(n_experiences)),
            "probs": probs
            }

    for i in range(n_different_samples):
        samples = np.random.choice(list(range(0, n_experiences)), n_classes,
                                   p=probs, replace=True)
        data[f"samples_{i}"] = samples

    # Plot
    fig, ax = plt.subplots(nrows=1, ncols=n_different_samples+1, figsize=(15, 3))
    plt.suptitle(title, fontsize=15)

    sns.lineplot(data=data, x="experiences", y="probs", ax=ax[0])
    ax[0].set(xlabel="Experience", ylabel="Probability")
    ax[0].set(xlim=(0, n_experiences))

    for i in range(n_different_samples):
        sns.histplot(data=data, x=f"samples_{i}", bins=n_classes,
                     ax=ax[i+1], binwidth=1.0, discrete=True, binrange=(0, n_experiences))
        ax[i+1].set(xlabel="Experience", ylabel="Number of Classes")
    plt.tight_layout()

# %% [markdown]
# # Zipf

# %%
n_experiences = 10
n_classes = 100
n_different_samples = 5

exponent = 0.0
title = f"Zipf - exponent {exponent}"
dist = {"n_entities": n_experiences, "dist_type": "zipf", "exponent": exponent}
probs = get_pmf(**dist)
sample_and_plot(n_experiences = n_experiences, n_classes = n_classes,
                n_different_samples = n_different_samples, probs = probs, title=title)
plt.savefig(os.path.join(output_path, f"{title}.pdf"))


exponent = 0.5
title = f"Zipf - exponent {exponent}"
dist = {"n_entities": n_experiences, "dist_type": "zipf", "exponent": exponent}
probs = get_pmf(**dist)
sample_and_plot(n_experiences = n_experiences, n_classes = n_classes,
                n_different_samples = n_different_samples, probs = probs, title=title)
plt.savefig(os.path.join(output_path, f"{title}.pdf"))

exponent = 1.0
title = f"Zipf - exponent {exponent}"
dist = {"n_entities": n_experiences, "dist_type": "zipf", "exponent": exponent}
probs = get_pmf(**dist)
sample_and_plot(n_experiences = n_experiences, n_classes = n_classes,
                n_different_samples = n_different_samples, probs = probs, title=title)
plt.savefig(os.path.join(output_path, f"{title}.pdf"))

# %% [markdown]
# ## Poisson

# %%
n_experiences = 10
n_classes = 100
n_different_samples = 5

mu = 0.0
title = f"Poisson - mu {mu}"
dist = {"n_entities": n_experiences, "dist_type": "poisson", "mu": mu}
probs = get_pmf(**dist)
sample_and_plot(n_experiences = n_experiences, n_classes = n_classes,
                n_different_samples = n_different_samples, probs = probs, title=title)
plt.savefig(os.path.join(output_path, f"{title}.pdf"))


mu = 3.0
title = f"Poisson - mu {mu}"
dist = {"n_entities": n_experiences, "dist_type": "poisson", "mu": mu}
probs = get_pmf(**dist)
sample_and_plot(n_experiences = n_experiences, n_classes = n_classes,
                n_different_samples = n_different_samples, probs = probs, title=title)
plt.savefig(os.path.join(output_path, f"{title}.pdf"))


mu = 15.0
title = f"Poisson - mu {mu}"
dist = {"n_entities": n_experiences, "dist_type": "poisson", "mu": mu}
probs = get_pmf(**dist)
sample_and_plot(n_experiences = n_experiences, n_classes = n_classes,
                n_different_samples = n_different_samples, probs = probs, title=title)
plt.savefig(os.path.join(output_path, f"{title}.pdf"))

# %% [markdown]
# ## Geometric

# %%
n_experiences = 10
n_classes = 100
n_different_samples = 5


p = 0.01
title = rf"Geometric - $p={p}$"
dist = {"n_entities": n_experiences, "dist_type": "geometric", "p": p}
probs = get_pmf(**dist)
sample_and_plot(n_experiences = n_experiences, n_classes = n_classes,
                n_different_samples = n_different_samples, probs = probs, title=title)
plt.savefig(os.path.join(output_path, f"{title}.pdf"))



p = 0.2
title = rf"Geometric - $p={p}$"
dist = {"n_entities": n_experiences, "dist_type": "geometric", "p": p}
probs = get_pmf(**dist)
sample_and_plot(n_experiences = n_experiences, n_classes = n_classes,
                n_different_samples = n_different_samples, probs = probs, title=title)
plt.savefig(os.path.join(output_path, f"{title}.pdf"))



p = 0.5
title = rf"Geometric - $p={p}$"
dist = {"n_entities": n_experiences, "dist_type": "geometric", "p": p}
probs = get_pmf(**dist)
sample_and_plot(n_experiences = n_experiences, n_classes = n_classes,
                n_different_samples = n_different_samples, probs = probs, title=title)
plt.savefig(os.path.join(output_path, f"{title}.pdf"))




p = 1.0
title = rf"Geometric - $p={p}$"
dist = {"n_entities": n_experiences, "dist_type": "geometric", "p": p}
probs = get_pmf(**dist)
sample_and_plot(n_experiences = n_experiences, n_classes = n_classes,
                n_different_samples = n_different_samples, probs = probs, title=title)
plt.savefig(os.path.join(output_path, f"{title}.pdf"))

# %% [markdown]
# # Uniform

# %%
title = f"Uniform"
dist = {"n_entities": n_experiences, "dist_type": "uniform"}
probs = get_pmf(**dist)
sample_and_plot(n_experiences = n_experiences, n_classes = n_classes,
                n_different_samples = n_different_samples, probs = probs, title=title)
plt.savefig(os.path.join(output_path, f"{title}.pdf"))

# %% [markdown]
# # Uniform  - Spread Factor

# %%
alpha = 0.1
title = f"Uniform - alpha: {alpha}"
dist = {"n_entities": n_experiences, "dist_type": "uniform_alpha", "alpha": alpha}
probs = get_pmf(**dist)
sample_and_plot(n_experiences = n_experiences, n_classes = n_classes,
                n_different_samples = n_different_samples, probs = probs, title=title)
plt.savefig(f"./{title}.pdf")

alpha = 0.5
title = f"Uniform - alpha: {alpha}"
dist = {"n_entities": n_experiences, "dist_type": "uniform_alpha", "alpha": alpha}
probs = get_pmf(**dist)
sample_and_plot(n_experiences = n_experiences, n_classes = n_classes,
                n_different_samples = n_different_samples, probs = probs, title=title)
plt.savefig(f"./{title}.pdf")


alpha = 1.0
title = f"Uniform - alpha: {alpha}"
dist = {"n_entities": n_experiences, "dist_type": "uniform_alpha", "alpha": alpha}
probs = get_pmf(**dist)
sample_and_plot(n_experiences = n_experiences, n_classes = n_classes,
                n_different_samples = n_different_samples, probs = probs, title=title)
plt.savefig(os.path.join(output_path, f"{title}.pdf"))

# %% [markdown]
# # Single Plot

# %%
n_experiences = 10
dist = {"n_entities": n_experiences, "dist_type": "poisson", "mu": 1.9}
probs = get_pmf(**dist)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 5))
data = {"Class": list(range(n_experiences)), "Probability": probs}
sns.barplot(data=data, x="Class", y="Probability", ax=ax)
ax.set_xticks(np.arange(0, n_experiences, 2))
ax.set_xlabel("Experience", fontsize=20)
ax.set_ylabel("Probability", fontsize=20)
ax.set_ylim(0, 1)
plt.tight_layout()
plt.savefig(os.path.join(output_path, "repetition.pdf"))
